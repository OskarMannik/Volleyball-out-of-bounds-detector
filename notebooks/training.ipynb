# %%
import sys
print(sys.executable)
print(sys.path)
#vaatame, kas jookseme ernelil
# Out:
# /gpfs/space/home/paskov/roboflow_env/bin/python
# ['', '/gpfs/space/software/cluster_software/spack/linux-centos7-x86_64/gcc-9.2.0/py-pip-23.0-pwaokfmlhc665pphxjg7comocqzloitx/lib/python3.7/site-packages', '/gpfs/space/software/jupyterhub/python/lib/python310.zip', '/gpfs/space/software/jupyterhub/python/lib/python3.10', '/gpfs/space/software/jupyterhub/python/lib/python3.10/lib-dynload', '/gpfs/space/home/paskov/roboflow_env/lib/python3.10/site-packages']

# %%
# !python -m venv ~/roboflow_env
#teeme env

# %%
# !source ~/roboflow_env/bin/activate
#aktiveerime

# %%
#tee kernelile resa, vali kernel roboflow_env
import sys
print(sys.executable)
print(sys.path)
#vaata, kas on ikka õige env

# %%
!~/roboflow_env/bin/pip install roboflow
#installi
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0 -> 24.0
# [notice] To update, run: /gpfs/space/home/paskov/roboflow_env/bin/python -m pip install --upgrade pip

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 gpfs/space/home/paskov/roboflow_env/bin/python(-m, pip, install, --upgrade, pip)
#
# NameError: name 'gpfs' is not defined

# %%
!~/roboflow_env/bin/pip install ipykernel
!~/roboflow_env/bin/python -m ipykernel install --user --name=roboflow_env
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/gpfs/space/home/paskov/roboflow_env/bin/python -m pip install --upgrade pip' command.
# Installed kernelspec roboflow_env in /gpfs/space/home/paskov/.local/share/jupyter/kernels/roboflow_env

# %%
# !pip install roboflow
# !pip install ultralytics

from roboflow import Roboflow
rf = Roboflow(api_key="snjPVQNpIqGUwQNA0Z4e")
project = rf.workspace("shukur-sabzaliev1").project("volleyball_v2")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.6 MB/s eta 0:00:00
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 6.0 MB/s eta 0:00:00
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 14.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 44.4 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 47.0 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# ...

# %%
import shutil

# %%
shutil.move("Volleyball_v2-2/train", "Volleyball_v2-2/Volleyball_v2-2/train",)
shutil.move("Volleyball_v2-2/test", "Volleyball_v2-2/Volleyball_v2-2/test")
shutil.move("Volleyball_v2-2/valid", "Volleyball_v2-2/Volleyball_v2-2/valid")
# Out:
# 'Volleyball_v2-2/Volleyball_v2-2/valid'

# %%
!~/roboflow_env/bin/pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.2.16-py3-none-any.whl (756 kB)
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
# ...
#   Using cached pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
# ...
#   Using cached torch-2.3.0-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
# ...
#   Using cached scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
# ...
#   Using cached torchvision-0.18.0-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
!~/roboflow_env/bin/pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.2.16
# Summary: Ultralytics YOLOv8 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page:
# Author: Glenn Jocher, Ayush Chaurasia, Jing Qiu
# Author-email:
# License: AGPL-3.0
# Location: /gpfs/space/home/paskov/roboflow_env/lib/python3.10/site-packages
# Requires: matplotlib, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, thop, torch, torchvision, tqdm
# Required-by:

# %%
!~/roboflow_env/bin/yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=50 imgsz=512
# Out:
# ...
# 100%|████████████████████████████████████████| 165M/165M [00:04<00:00, 37.7MB/s]
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.1 torch-2.3.0+cu121 CUDA:0 (Tesla V100-PCIE-32GB, 32494MiB)
# ...

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O miniconda.sh
# !bash miniconda.sh -b -p $HOME/miniconda
# !export PATH="$HOME/miniconda/bin:$PATH"
# !conda init
# Out:
# --2024-05-17 11:10:24--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143351488 (137M) [application/octet-stream]
# Saving to: ‘miniconda.sh’
#
# 100%[======================================>] 143,351,488  277MB/s   in 0.5s
#
# 2024-05-17 11:10:25 (277 MB/s) - ‘miniconda.sh’ saved [143351488/143351488]
#
# PREFIX=/gpfs/space/home/paskov/miniconda
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
# ...

# %%
# !$HOME/miniconda/bin/conda create -n roboflow_env python=3.10 -y
# !$HOME/miniconda/bin/conda init bash
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /gpfs/space/home/paskov/miniconda/envs/roboflow_env
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h5eee18b_6         262 KB
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     openssl-3.0.13             |       h7f8727e_1         5.2 MB
#     pip-24.0                   |  py310h06a4308_0         2.7 MB
#     python-3.10.14             |       h955ad1f_1        26.8 MB
#     setuptools-69.5.1          |  py310h06a4308_0        1012 KB
#     sqlite-3.45.3              |       h5eee18b_0         1.2 MB
#     tk-8.6.14                  |       h39e8969_0         3.4 MB
#     wheel-0.43.0               |  py310h06a4308_0         110 KB
# ...

# %%
# !$HOME/miniconda/envs/roboflow_env/bin/pip install roboflow ultralytics
# Out:
# ...
#   Using cached roboflow-1.1.29-py3-none-any.whl (74 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# ...
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# ...
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# ...
#   Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# ...
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# ...
#   Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# ...
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# ...
#   Using cached opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
# ...
#   Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# ...
#   Using cached PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...

# %%
# !$HOME/miniconda/envs/roboflow_env/bin/pip install ipykernel
# !$HOME/miniconda/envs/roboflow_env/bin/python -m ipykernel install --user --name=roboflow_env --display-name "Python (roboflow_env)"
# Out:
# ...
#   Using cached ipykernel-6.29.4-py3-none-any.whl (117 kB)
# ...
#   Using cached pyzmq-26.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (919 kB)
# ...
#   Using cached jupyter_client-8.6.1-py3-none-any.whl (105 kB)
# ...
#   Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# ...
#   Using cached ipython-8.24.0-py3-none-any.whl (816 kB)
# ...
#   Using cached tornado-6.4-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
# ...
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# ...
#   Using cached debugpy-1.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# ...
#   Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# ...
#   Using cached jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# ...
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# ...
#   Using cached pygments-2.18.0-py3-none-any.whl (1.2 MB)
# ...
#   Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# ...
#   Using cached prompt_toolkit-3.0.43-py3-none-any.whl (386 kB)
# ...

# %%
# !$HOME/miniconda/envs/roboflow_env/bin/pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.2.16
# Summary: Ultralytics YOLOv8 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page:
# Author: Glenn Jocher, Ayush Chaurasia, Jing Qiu
# Author-email:
# License: AGPL-3.0
# Location: /gpfs/space/home/paskov/.local/lib/python3.10/site-packages
# Requires: matplotlib, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, thop, torch, torchvision, tqdm
# Required-by:

# %%
# !source $HOME/miniconda/bin/activate roboflow_env

# %%
# Reinstall ultralytics in the Conda environment
# !$HOME/miniconda/envs/roboflow_env/bin/pip install --force-reinstall ultralytics

# Verify ultralytics installation in the Conda environment
# !$HOME/miniconda/envs/roboflow_env/bin/pip show ultralytics
# Out:
# ...
#   Using cached ultralytics-8.2.16-py3-none-any.whl (756 kB)
# ...
#   Using cached pillow-10.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#   Using cached torch-2.3.0-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
# ...
#   Using cached torchvision-0.18.0-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
# ...
#   Using cached psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
# ...
#   Using cached pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
# ...
#   Using cached scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
# ...
#   Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# ...

# %%
# Create the YOLO script
with open("run_yolo.py", "w") as file:
    file.write("""
from ultralytics import YOLO

# Load a model
model = YOLO('yolov5l6u.pt')  # pass any model here

# Train the model
model.train(data='Volleyball_v2-2/data.yaml', epochs=50, imgsz=256)
""")

# Run the Python script using the Conda environment's Python
# !$HOME/miniconda/envs/roboflow_env/bin/python run_yolo.py
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.14 torch-2.3.0+cu121 CPU (AMD EPYC 7763 64-Core Processor)
# ...

# %%
# Updated script to create the YOLO training script
with open("run_yolo.py", "w") as file:
    file.write("""
from ultralytics import YOLO

# Load a model
model = YOLO('runs/detect/train8/weights/last.pt')  # pass any model here

# Train the model with weights
model.train(data='Volleyball_v2-2/data.yaml', epochs=15, imgsz=256)
""")

# Note: The command to run the Python script seems fine as is.
# !$HOME/miniconda/envs/roboflow_env/bin/python run_yolo.py
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.14 torch-2.3.0+cu121 CUDA:0 (Tesla V100-SXM2-32GB, 32494MiB)
# ...

# %%
# Updated script to create the YOLO training script
with open("run_yolo.py", "w") as file:
    file.write("""
from ultralytics import YOLO

# Load a model
model = YOLO('runs/detect/train12/weights/best.pt')  # pass any model here

# Train the model with weights
model.train(data='Volleyball_v2-2/data.yaml', epochs=10, imgsz=512)
""")

# Note: The command to run the Python script seems fine as is.
# !$HOME/miniconda/envs/roboflow_env/bin/python run_yolo.py
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.14 torch-2.3.0+cu121 CUDA:0 (Tesla V100-SXM2-32GB, 32494MiB)
# ...
